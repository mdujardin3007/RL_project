# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Lunar_Lander/
# Out:
# /content/drive/MyDrive/Lunar_Lander

# %% [markdown]
# Installing the needed libraires

# %%
# !apt-get install -y xvfb ffmpeg
# !pip install pyvirtualdisplay
# !pip install gymnasium[box2d]
# !pip install stable-baselines3
# !pip install moviepy
# !pip install swig
# !pip install "gymnasium[box2d]"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xvfb
# 0 upgraded, 9 newly installed, 0 to remove and 30 not upgraded.
# Need to get 7,817 kB of archives.
# After this operation, 12.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.14 [29.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.14 [866 kB]
# Fetched 7,817 kB in 0s (18.1 MB/s)
# Selecting previously unselected package libfontenc1:amd64.
# (Reading database ... 126210 files and directories currently installed.)
# Preparing to unpack .../0-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../1-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../2-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../3-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../4-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../5-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../6-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../7-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.14_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.14) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../8-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.14_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.14) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.14) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.14) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (4.13.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.6.1)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 41.6 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for box2d-py (setup.py) ... error
#   ERROR: Failed building wheel for box2d-py
#   Running setup.py clean for box2d-py
# Failed to build box2d-py
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (box2d-py)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (1.1.1)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.6.0+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3) (4.13.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 82.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 68.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable-baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable-baselines3-2.6.0
# Requirement already satisfied: moviepy in /usr/local/lib/python3.11/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.11/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy) (0.6.0)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.11/dist-packages (from moviepy) (4.67.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.0.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio<3.0,>=2.5->moviepy) (11.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2025.1.31)
# Collecting swig
#   Using cached swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (3.5 kB)
# Using cached swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
# Installing collected packages: swig
# Successfully installed swig-4.3.0
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (4.13.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (4.3.0)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp311-cp311-linux_x86_64.whl size=2379448 sha256=6a412928021fae638a09d69c16a191b0e9612e9ede44451adaf5ab1d55e47b12
#   Stored in directory: /root/.cache/pip/wheels/ab/f1/0c/d56f4a2bdd12bae0a0693ec33f2f0daadb5eb9753c78fa5308
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.5

# %% [markdown]
# Importing the needed librairies

# %%
import gymnasium as gym
from pyvirtualdisplay import Display
from gymnasium.wrappers import RecordVideo
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

# %% [markdown]
# Our hyperparameters are in config.py

# %% [markdown]
# We import the core components for PPO with Reward Shaping & Normalization, from the ppo_components.py file

# %% [markdown]
# This script (`train_ppo.py`) trains a PPO agent on the `CustomLunarLander-v0` environment. Here's a succinct overview of what the script does:
#
# 1. **Initialization**:
#    - Initializes the actor-critic model, optimizer, and a running normalizer for state inputs.
#    - Creates the environment and extracts the state and action dimensions.
#
# 2. **Rollout Collection**:
#    - Collects a fixed number of interactions (rollouts) from the environment (e.g., 2048 steps).
#    - Stores the states, actions, rewards, log probabilities, done flags, and value estimates in a rollout buffer.
#    - Applies reward shaping (small penalties) based on specific conditions (e.g., vertical speed).
#
# 3. **Advantage and Return Calculation**:
#    - Computes advantages using Generalized Advantage Estimation (GAE).
#    - Calculates returns by adding the advantages to the corresponding value estimates.
#
# 4. **Model Update**:
#    - Converts the collected data into tensors.
#    - Splits the data into mini-batches and performs multiple epochs of updates.
#    - Optimizes the PPO loss, which includes the policy loss (with clipping), value loss, and an entropy bonus for exploration.
#
# 5. **Logging and Saving**:
#    - Logs training metrics such as average return, policy loss, value loss, entropy, KL divergence, and explained variance.
#    - Saves the best model (based on average return) and the final model at the end of training.
#
# This modular approach, along with the separation of core components into `ppo_components.py`, helps maintain clean and reusable code.

# %%
# !python train_ppo.py
# Out:
# Device: cpu
# /content/drive/MyDrive/Lunar_Lander/train_ppo.py:100: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   states = torch.FloatTensor(buffer.states).to(device)
# Update 1, Average Reward: -178.24
# Update 2, Average Reward: -185.67
# Update 3, Average Reward: -150.89
# Update 4, Average Reward: -170.76
# Update 5, Average Reward: -171.29
# Update 6, Average Reward: -179.57
# Update 7, Average Reward: -151.13
# Update 8, Average Reward: -144.99
# Update 9, Average Reward: -132.79
# Update 10, Average Reward: -136.17
# Update 11, Average Reward: -146.91
# Update 12, Average Reward: -142.88
# Update 13, Average Reward: -176.77
# Update 14, Average Reward: -170.11
# Update 15, Average Reward: -208.65
# Update 16, Average Reward: -153.96
# Update 17, Average Reward: -167.44
# Update 18, Average Reward: -142.47
# Update 19, Average Reward: -179.22
# Update 20, Average Reward: -146.51
# Update 21, Average Reward: -123.85
# Update 22, Average Reward: -142.93
# Update 23, Average Reward: -178.36
# Update 24, Average Reward: -118.19
# Update 25, Average Reward: -123.31
# Update 26, Average Reward: -120.78
# Update 27, Average Reward: -126.05
# Update 28, Average Reward: -140.63
# Update 29, Average Reward: -92.62
# Update 30, Average Reward: -127.62
# Update 31, Average Reward: -107.44
# Update 32, Average Reward: -98.76
# Update 33, Average Reward: -98.36
# Update 34, Average Reward: -84.52
# Update 35, Average Reward: -96.45
# Update 36, Average Reward: -70.89
# Update 37, Average Reward: -92.31
# Update 38, Average Reward: -106.56
# Update 39, Average Reward: -86.65
# Update 40, Average Reward: -82.26
# Update 41, Average Reward: -84.57
# Update 42, Average Reward: -97.54
# Update 43, Average Reward: -186.05
# Update 44, Average Reward: -156.65
# Update 45, Average Reward: -200.43
# Update 46, Average Reward: -81.42
# Update 47, Average Reward: -144.81
# Update 48, Average Reward: -105.49
# Update 49, Average Reward: -84.61
# Update 50, Average Reward: -136.88
# Update 51, Average Reward: -86.92
# Update 52, Average Reward: -96.26
# Update 53, Average Reward: -127.80
# Update 54, Average Reward: -71.84
# Update 55, Average Reward: -76.58
# Update 56, Average Reward: -149.87
# Update 57, Average Reward: -112.74
# Update 58, Average Reward: -58.63
# Update 59, Average Reward: -72.62
# Update 60, Average Reward: -83.88
# Update 61, Average Reward: -52.42
# Update 62, Average Reward: -77.10
# Update 63, Average Reward: -49.99
# Update 64, Average Reward: -39.17
# Update 65, Average Reward: -138.11
# Update 66, Average Reward: -122.61
# Update 67, Average Reward: -48.86
# Update 68, Average Reward: -48.93
# Update 69, Average Reward: -80.91
# Update 70, Average Reward: -50.50
# Update 71, Average Reward: -31.83
# Update 72, Average Reward: -24.50
# Update 73, Average Reward: -62.80
# Update 74, Average Reward: -45.73
# Update 75, Average Reward: -50.83
# Update 76, Average Reward: -39.36
# Update 77, Average Reward: -57.82
# Update 78, Average Reward: -26.26
# Update 79, Average Reward: -88.59
# Update 80, Average Reward: -73.78
# Update 81, Average Reward: -28.56
# Update 82, Average Reward: -80.46
# Update 83, Average Reward: -111.78
# Update 84, Average Reward: -33.20
# Update 85, Average Reward: -67.82
# Update 86, Average Reward: -55.34
# Update 87, Average Reward: -58.53
# Update 88, Average Reward: -37.76
# Update 89, Average Reward: -56.10
# Update 90, Average Reward: -45.06
# Update 91, Average Reward: -34.94
# Update 92, Average Reward: -27.13
# Update 93, Average Reward: -55.30
# Update 94, Average Reward: -33.45
# Update 95, Average Reward: -14.31
# Update 96, Average Reward: -44.01
# Update 97, Average Reward: 3.71
# Update 98, Average Reward: -38.41
# Update 99, Average Reward: -54.68
# Update 100, Average Reward: -89.66
# Update 101, Average Reward: -103.93
# Update 102, Average Reward: -127.31
# Update 103, Average Reward: -80.21
# Update 104, Average Reward: -112.72
# Update 105, Average Reward: -126.47
# Update 106, Average Reward: -6.76
# Update 107, Average Reward: -128.43
# Update 108, Average Reward: -275.54
# Update 109, Average Reward: -167.50
# Update 110, Average Reward: -87.36
# Update 111, Average Reward: -174.90
# Update 112, Average Reward: -26.72
# Update 113, Average Reward: -173.96
# Update 114, Average Reward: -172.00
# Update 115, Average Reward: -136.29
# Update 116, Average Reward: -67.03
# Update 117, Average Reward: -149.93
# Update 118, Average Reward: -146.33
# Update 119, Average Reward: -234.44
# Update 120, Average Reward: -342.07
# Update 121, Average Reward: -173.72
# Update 122, Average Reward: -233.31
# Update 123, Average Reward: -157.39
# Update 124, Average Reward: -153.49
# Update 125, Average Reward: -264.76
# Update 126, Average Reward: -140.02
# Update 127, Average Reward: -189.12
# Update 128, Average Reward: -273.35
# Update 129, Average Reward: -265.18
# Update 130, Average Reward: -237.47
# Update 131, Average Reward: -207.49
# Update 132, Average Reward: -213.84
# Update 133, Average Reward: -239.33
# Update 134, Average Reward: -211.42
# Update 135, Average Reward: -198.63
# Update 136, Average Reward: -195.94
# Update 137, Average Reward: -189.64
# Update 138, Average Reward: -231.38
# Update 139, Average Reward: -168.50
# Update 140, Average Reward: -206.39
# Update 141, Average Reward: -173.38
# Update 142, Average Reward: -207.89
# Update 143, Average Reward: -197.30
# Update 144, Average Reward: -150.13
# Update 145, Average Reward: -165.25
# Update 146, Average Reward: -172.79
# Update 147, Average Reward: -156.46
# Update 148, Average Reward: -156.63
# Update 149, Average Reward: -124.43
# Update 150, Average Reward: -69.62
# Update 151, Average Reward: -183.53
# Update 152, Average Reward: -99.94
# Update 153, Average Reward: -98.48
# Update 154, Average Reward: -80.52
# Update 155, Average Reward: -147.45
# Update 156, Average Reward: -63.98
# Update 157, Average Reward: -32.34
# Update 158, Average Reward: -108.39
# Update 159, Average Reward: -32.47
# Update 160, Average Reward: -43.17
# Update 161, Average Reward: -84.10
# Update 162, Average Reward: 46.55
# Update 163, Average Reward: -192.06
# Update 164, Average Reward: -79.68
# Update 165, Average Reward: -86.60
# Update 166, Average Reward: -48.28
# Update 167, Average Reward: 48.98
# Update 168, Average Reward: 97.24
# Update 169, Average Reward: 8.13
# Update 170, Average Reward: 46.04
# Update 171, Average Reward: 17.22
# Update 172, Average Reward: 138.19
# Update 173, Average Reward: -29.18
# Update 174, Average Reward: 43.73
# Update 175, Average Reward: 178.74
# Update 176, Average Reward: -34.04
# Update 177, Average Reward: -31.80
# Update 178, Average Reward: 92.50
# Update 179, Average Reward: 73.96
# Update 180, Average Reward: -33.85
# Update 181, Average Reward: 162.59
# Update 182, Average Reward: -85.11
# Update 183, Average Reward: -22.83
# Update 184, Average Reward: 18.27
# Update 185, Average Reward: 48.83
# Update 186, Average Reward: 19.87
# Update 187, Average Reward: 65.00
# Update 188, Average Reward: 139.87
# Update 189, Average Reward: 120.11
# Update 190, Average Reward: 154.71
# Update 191, Average Reward: 55.82
# Update 192, Average Reward: 30.85
# Update 193, Average Reward: -64.50
# Update 194, Average Reward: 160.86
# Update 195, Average Reward: -4.62
# Update 196, Average Reward: 125.43
# Update 197, Average Reward: 111.01
# Update 198, Average Reward: 122.04
# Update 199, Average Reward: 8.56
# Update 200, Average Reward: -34.57
# Update 201, Average Reward: 161.57
# Update 202, Average Reward: 119.70
# Update 203, Average Reward: -138.89
# Update 204, Average Reward: -23.48
# Update 205, Average Reward: -60.95
# Update 206, Average Reward: 97.49
# Update 207, Average Reward: -43.92
# Update 208, Average Reward: 135.49
# Update 209, Average Reward: -66.25
# Update 210, Average Reward: 16.25
# Update 211, Average Reward: 110.47
# Update 212, Average Reward: 146.28
# Update 213, Average Reward: 145.90
# Update 214, Average Reward: 71.14
# Update 215, Average Reward: 110.74
# Update 216, Average Reward: 156.96
# Update 217, Average Reward: 152.83
# Update 218, Average Reward: -14.96
# Update 219, Average Reward: 23.31
# Update 220, Average Reward: 71.42
# Update 221, Average Reward: 67.84
# Update 222, Average Reward: 105.92
# Update 223, Average Reward: 8.13
# Update 224, Average Reward: -82.00
# Update 225, Average Reward: 142.48
# Update 226, Average Reward: 54.90
# Update 227, Average Reward: 154.27
# Update 228, Average Reward: 49.70
# Update 229, Average Reward: 30.71
# Update 230, Average Reward: -36.76
# Update 231, Average Reward: 152.66
# Update 232, Average Reward: 161.86
# Update 233, Average Reward: 177.97
# Update 234, Average Reward: 145.53
# Update 235, Average Reward: 150.17
# Update 236, Average Reward: 87.32
# Update 237, Average Reward: 42.21
# Update 238, Average Reward: 69.59
# Update 239, Average Reward: 149.92
# Update 240, Average Reward: 111.95
# Update 241, Average Reward: 202.19
# Update 242, Average Reward: 103.01
# Update 243, Average Reward: 73.33
# Update 244, Average Reward: -27.97
# Update 245, Average Reward: 124.26
# Update 246, Average Reward: 154.28
# Update 247, Average Reward: 43.00
# Update 248, Average Reward: -14.65
# Update 249, Average Reward: 121.11
# Update 250, Average Reward: 92.20
# Update 251, Average Reward: 171.78
# Update 252, Average Reward: 76.36
# Update 253, Average Reward: 156.72
# Update 254, Average Reward: 113.06
# Update 255, Average Reward: 118.05
# Update 256, Average Reward: 144.13
# Update 257, Average Reward: 171.59
# Update 258, Average Reward: 127.90
# Update 259, Average Reward: 132.40
# Update 260, Average Reward: 148.84
# Update 261, Average Reward: 149.87
# Update 262, Average Reward: 137.82
# Update 263, Average Reward: 127.81
# Update 264, Average Reward: 166.42
# Update 265, Average Reward: 150.29
# Update 266, Average Reward: 110.23
# Update 267, Average Reward: 126.69
# Update 268, Average Reward: 126.27
# Update 269, Average Reward: 130.07
# Update 270, Average Reward: 157.60
# Update 271, Average Reward: 94.38
# Update 272, Average Reward: 133.72
# Update 273, Average Reward: 157.85
# Update 274, Average Reward: 147.51
# Update 275, Average Reward: 144.65
# Update 276, Average Reward: 91.26
# Update 277, Average Reward: 168.43
# Update 278, Average Reward: 126.55
# Update 279, Average Reward: 149.31
# Update 280, Average Reward: 56.21
# Update 281, Average Reward: 160.45
# Update 282, Average Reward: 184.24
# Update 283, Average Reward: 183.92
# Update 284, Average Reward: 170.69
# Update 285, Average Reward: 178.03
# Update 286, Average Reward: 97.73
# Update 287, Average Reward: 173.49
# Update 288, Average Reward: 197.45
# Update 289, Average Reward: 129.31
# Update 290, Average Reward: 108.84
# Update 291, Average Reward: 158.37
# Update 292, Average Reward: 169.32
# Update 293, Average Reward: 140.31
# Update 294, Average Reward: 114.67
# Update 295, Average Reward: 155.28
# Update 296, Average Reward: 120.65
# Update 297, Average Reward: 151.16
# Update 298, Average Reward: 140.81
# Update 299, Average Reward: 130.88
# Update 300, Average Reward: 108.12
# Update 301, Average Reward: 155.44
# Update 302, Average Reward: 139.46
# Update 303, Average Reward: 157.59
# Update 304, Average Reward: 167.60
# Update 305, Average Reward: 154.76
# Update 306, Average Reward: 139.06
# Update 307, Average Reward: 77.96
# Update 308, Average Reward: 127.30
# Update 309, Average Reward: 90.26
# Update 310, Average Reward: 124.32
# Update 311, Average Reward: 73.73
# Update 312, Average Reward: 160.25
# Update 313, Average Reward: 135.85
# Update 314, Average Reward: 227.33
# Update 315, Average Reward: 132.02
# Update 316, Average Reward: 64.22
# Update 317, Average Reward: 98.89
# Update 318, Average Reward: 126.35
# Update 319, Average Reward: 82.05
# Update 320, Average Reward: 114.92
# Update 321, Average Reward: 143.20
# Update 322, Average Reward: 156.41
# Update 323, Average Reward: 109.42
# Update 324, Average Reward: 147.04
# Update 325, Average Reward: 148.57
# Update 326, Average Reward: 136.06
# Update 327, Average Reward: 149.82
# Update 328, Average Reward: 158.69
# Update 329, Average Reward: 175.35
# Update 330, Average Reward: 133.91
# Update 331, Average Reward: 152.60
# Update 332, Average Reward: 129.07
# Update 333, Average Reward: 170.96
# Update 334, Average Reward: 164.47
# Update 335, Average Reward: 124.86
# Update 336, Average Reward: 151.63
# Update 337, Average Reward: 90.22
# Update 338, Average Reward: 145.03
# Update 339, Average Reward: 107.35
# Update 340, Average Reward: 165.54
# Update 341, Average Reward: 127.39
# Update 342, Average Reward: 153.52
# Update 343, Average Reward: 152.50
# Update 344, Average Reward: 96.68
# Update 345, Average Reward: 156.08
# Update 346, Average Reward: 71.58
# Update 347, Average Reward: 70.73
# Update 348, Average Reward: 103.60
# Update 349, Average Reward: 109.53
# Update 350, Average Reward: 126.39
# Update 351, Average Reward: 53.92
# Update 352, Average Reward: 160.86
# Update 353, Average Reward: 111.27
# Update 354, Average Reward: 105.08
# Update 355, Average Reward: 162.59
# Update 356, Average Reward: 96.37
# Update 357, Average Reward: 119.21
# Update 358, Average Reward: 132.85
# Update 359, Average Reward: 74.75
# Update 360, Average Reward: 145.50
# Update 361, Average Reward: 149.13
# Update 362, Average Reward: 144.80
# Update 363, Average Reward: 128.93
# Update 364, Average Reward: 162.02
# Update 365, Average Reward: 82.95
# Update 366, Average Reward: 126.59
# Update 367, Average Reward: 152.66
# Update 368, Average Reward: 176.71
# Update 369, Average Reward: 162.25
# Update 370, Average Reward: 70.88
# Update 371, Average Reward: 169.40
# Update 372, Average Reward: 172.86
# Update 373, Average Reward: 112.09
# Update 374, Average Reward: 183.62
# Update 375, Average Reward: 125.12
# Update 376, Average Reward: 114.61
# Update 377, Average Reward: 152.08
# Update 378, Average Reward: 131.24
# Update 379, Average Reward: 139.12
# Update 380, Average Reward: 93.06
# Update 381, Average Reward: 165.86
# Update 382, Average Reward: 103.82
# Update 383, Average Reward: 119.23
# Update 384, Average Reward: 144.34
# Update 385, Average Reward: 170.13
# Update 386, Average Reward: 136.85
# Update 387, Average Reward: 181.74
# Update 388, Average Reward: 165.83
# Update 389, Average Reward: 75.99
# Update 390, Average Reward: 115.46
# Update 391, Average Reward: 56.43
# Update 392, Average Reward: 135.20
# Update 393, Average Reward: 158.17
# Update 394, Average Reward: 47.25
# Update 395, Average Reward: 116.62
# Update 396, Average Reward: 160.95
# Update 397, Average Reward: 143.69
# Update 398, Average Reward: 66.30
# Update 399, Average Reward: 102.41
# Update 400, Average Reward: 144.81
# Update 401, Average Reward: 92.31
# Update 402, Average Reward: 119.08
# Update 403, Average Reward: 168.97
# Update 404, Average Reward: 72.79
# Update 405, Average Reward: 70.53
# Update 406, Average Reward: 110.49
# Update 407, Average Reward: 61.41
# Update 408, Average Reward: 68.08
# Update 409, Average Reward: 142.74
# Update 410, Average Reward: 156.08
# Update 411, Average Reward: 188.68
# Update 412, Average Reward: 98.99
# Update 413, Average Reward: 91.92
# Update 414, Average Reward: 95.64
# Update 415, Average Reward: 93.73
# Update 416, Average Reward: 81.35
# Update 417, Average Reward: 2.68
# Update 418, Average Reward: 2.55
# Update 419, Average Reward: 101.32
# Update 420, Average Reward: 128.09
# Update 421, Average Reward: 5.53
# Update 422, Average Reward: 121.16
# Update 423, Average Reward: 163.01
# Update 424, Average Reward: -5.36
# Update 425, Average Reward: -66.81
# Update 426, Average Reward: -80.84
# Update 427, Average Reward: -138.24
# Update 428, Average Reward: -138.20
# Update 429, Average Reward: -187.38
# Update 430, Average Reward: -37.05
# Update 431, Average Reward: 166.18
# Update 432, Average Reward: 144.21
# Update 433, Average Reward: 259.42
# Update 434, Average Reward: 108.94
# Update 435, Average Reward: 164.46
# Update 436, Average Reward: 212.46
# Update 437, Average Reward: 155.64
# Update 438, Average Reward: 111.29
# Update 439, Average Reward: 111.47
# Update 440, Average Reward: 232.73
# Update 441, Average Reward: 200.53
# Update 442, Average Reward: 184.84
# Update 443, Average Reward: 190.11
# Update 444, Average Reward: 125.53
# Update 445, Average Reward: 182.90
# Update 446, Average Reward: 186.97
# Update 447, Average Reward: 76.67
# Update 448, Average Reward: 198.92
# Update 449, Average Reward: 160.71
# Update 450, Average Reward: 264.60
# Update 451, Average Reward: 144.01
# Update 452, Average Reward: 211.75
# Update 453, Average Reward: 162.79
# Update 454, Average Reward: 150.47
# Update 455, Average Reward: 111.49
# Update 456, Average Reward: 104.34
# Update 457, Average Reward: 152.99
# Update 458, Average Reward: 129.98
# Update 459, Average Reward: 214.17
# Update 460, Average Reward: 115.71
# Update 461, Average Reward: 255.88
# Update 462, Average Reward: 117.04
# Update 463, Average Reward: 128.57
# Update 464, Average Reward: 209.36
# Update 465, Average Reward: 231.35
# Update 466, Average Reward: 141.80
# Update 467, Average Reward: 230.10
# Update 468, Average Reward: 151.91
# Update 469, Average Reward: 206.90
# Update 470, Average Reward: 198.18
# Update 471, Average Reward: 200.99
# Update 472, Average Reward: 254.24
# Update 473, Average Reward: 191.83
# Update 474, Average Reward: 84.00
# Update 475, Average Reward: 104.41
# Update 476, Average Reward: 244.21
# Update 477, Average Reward: 211.74
# Update 478, Average Reward: 168.67
# Update 479, Average Reward: 195.69
# Update 480, Average Reward: 171.42
# Update 481, Average Reward: 214.89
# Update 482, Average Reward: 226.75
# Update 483, Average Reward: 175.26
# Update 484, Average Reward: 233.43
# Update 485, Average Reward: 204.60
# Update 486, Average Reward: 249.63
# Update 487, Average Reward: 216.59
# Update 488, Average Reward: 181.51
# Update 489, Average Reward: 215.92
# Update 490, Average Reward: 217.53
# Update 491, Average Reward: 251.19
# Update 492, Average Reward: 211.89
# Update 493, Average Reward: 126.08
# Update 494, Average Reward: 237.81
# Update 495, Average Reward: 242.53
# Update 496, Average Reward: 208.78
# Update 497, Average Reward: 224.92
# Update 498, Average Reward: 205.57
# Update 499, Average Reward: 176.75
# Update 500, Average Reward: 273.83

# %% [markdown]
# This script loads the training metrics saved in `training_logs_.npz` (which include average return, policy loss, value loss, entropy, KL divergence, and explained variance). It then creates three subplots:
#
# - **Learning Signal:** Plots the average return (scaled) and explained variance.
# - **Losses:** Plots the policy loss and value loss.
# - **Policy Behavior:** Plots the entropy and KL divergence.
#
# Each plot uses twin y-axes to display two metrics on the same graph, with proper labels, titles, and legends to ensure clarity. At the end of the script, the plots are displayed using `plt.show()`.

# %%
# %matplotlib inline
# %run plot_training_logs.py

# %% [markdown]
# These plots show the evolution of key metrics during the training of a PPO agent.
#
# - **Average Return (blue):**
#   Represents the mean reward accumulated over one or more episodes within each update cycle. As we can see, it is increasing on average during the 500 epochs. However, it has a non-negligible variance due to the exploration of the agent.
#
# - **Explained Variance (green):**
#   Measures how well the value function predictions explain the actual returns. It rapidly converges towards 0.9, meaning that during the training the agent explains its future outcomes well.
#
# - **Policy Loss (red):**
#   It reflects how the agent’s policy is updated. Here, the policy is converging to an optimum. However, there are spikes when the policy drastically changes in a single update or if exploration leads to sudden changes in performance. We can see that for some of the spikes, the average returns are changing drastically.
#
# - **Value Loss (orange):**
#   It indicates how well the value function fits the observed returns. It is  quickly decreasing at the beginning, just when the explained variance increases. It makes sense because it implies that the critic is learning to predict returns more accurately.
#
# - **Entropy (purple):**
#   Entropy shows the level of randomness or exploration in the policy. High entropy means the agent is exploring various actions, while lower entropy suggests more deterministic actions. The gradual decrease over time we can see is common, as the agent becomes more certain of the best actions.
#
# - **KL Divergence (brown):**
#   Finally, the KL Divergence measures how much the current policy diverges from the old policy. In PPO, if KL divergence becomes too large, it indicates that updates may be overly aggressive, potentially destabilizing learning. We can see that spikes in the KL divergence occur at the same time as the policy loss spikes.

# %%
# !python record_video.py
# Out:
# /usr/local/lib/python3.11/dist-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /content/drive/MyDrive/Lunar_Lander/video folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(

# %%
import display_video
display_video.show_video()
# Out:
#         <video width=700 controls>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %%
from evaluate_and_record import evaluate_and_record
results = evaluate_and_record()
# Out:
# Evaluating: 100%|██████████| 500/500 [01:09<00:00,  7.22it/s]

# %%
import plot_results
plot_results.plot_results(results)

# %%
import evaluate_fuel
evaluate_fuel.evaluate_fuel()
# Out:
# Evaluating Fuel Level: 50
# Fuel 50: 100%|██████████| 100/100 [00:06<00:00, 15.53it/s]
# Avg Reward for Fuel 50: -100.48
#
# Evaluating Fuel Level: 100
# Fuel 100: 100%|██████████| 100/100 [00:07<00:00, 12.61it/s]
# Avg Reward for Fuel 100: -41.46
#
# Evaluating Fuel Level: 150
# Fuel 150: 100%|██████████| 100/100 [00:12<00:00,  8.08it/s]
# Avg Reward for Fuel 150: 47.90
#
# Evaluating Fuel Level: 200
# Fuel 200: 100%|██████████| 100/100 [00:13<00:00,  7.19it/s]
# Avg Reward for Fuel 200: 228.43
#
# Evaluating Fuel Level: 250
# Fuel 250: 100%|██████████| 100/100 [00:13<00:00,  7.63it/s]
# Avg Reward for Fuel 250: 286.72
#
# Evaluating Fuel Level: 300
# Fuel 300: 100%|██████████| 100/100 [00:12<00:00,  7.79it/s]
# Avg Reward for Fuel 300: 292.74
